# %%
import argparse
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
import time

# %%
# load the train and test data
xTrain = pd.read_csv("q4xTrain.csv")
yTrain = pd.read_csv("q4yTrain.csv")
xTest = pd.read_csv("q4xTest.csv")
yTest = pd.read_csv("q4yTest.csv")

# %%
dtClass = DecisionTreeClassifier()
knn = KNeighborsClassifier()

# %%
gridSearchKnn = GridSearchCV(knn, {'n_neighbors': range(1, 41, 2)})
gridSearchKnn.fit(xTrain, yTrain.values.ravel())
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_neighbors': range(1, 41, 2)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print("Best parameters set found on development set:")
print()
print(gridSearchKnn.best_score_, gridSearchKnn.best_params_)
print()
print("Grid scores on development set:")
print()
means = gridSearchKnn.cv_results_['mean_test_score']
for mean, params in zip(means, gridSearchKnn.cv_results_['params']):
    print("%0.12f for %r" % (mean, params))
print()
# Out:
# Best parameters set found on development set:
#
# 0.8650624599615631 {'n_neighbors': 21}
#
# Grid scores on development set:
#
# 0.842729019859 for {'n_neighbors': 1}
# 0.853459320948 for {'n_neighbors': 3}
# 0.855245035234 for {'n_neighbors': 5}
# 0.849863869315 for {'n_neighbors': 7}
# 0.857014734145 for {'n_neighbors': 9}
# 0.862375880846 for {'n_neighbors': 11}
# 0.864165598975 for {'n_neighbors': 13}
# 0.863272741832 for {'n_neighbors': 15}
# 0.862379884689 for {'n_neighbors': 17}
# 0.864169602819 for {'n_neighbors': 19}
# 0.865062459962 for {'n_neighbors': 21}
# 0.865062459962 for {'n_neighbors': 23}
# 0.865058456118 for {'n_neighbors': 25}
# 0.865058456118 for {'n_neighbors': 27}
# 0.865058456118 for {'n_neighbors': 29}
# 0.865058456118 for {'n_neighbors': 31}
# 0.864165598975 for {'n_neighbors': 33}
# 0.864165598975 for {'n_neighbors': 35}
# 0.864165598975 for {'n_neighbors': 37}
# 0.864165598975 for {'n_neighbors': 39}

# %%
test_params = [{"criterion": ['gini', 'entropy'],
        "max_depth": range(1, 21),
        "min_samples_leaf": [1, 2, 4, 8, 16, 32, 64, 128, 256, 512],}]
gridSearchDT = GridSearchCV(dtClass, test_params)
gridSearchDT.fit(xTrain, yTrain.values.ravel())
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'max_depth': range(1, 21),
#                           'min_samples_leaf': [1, 2, 4, 8, 16, 32, 64, 128, 256,
#                                                512]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print("Best parameters set found on development set:")
print()
print(gridSearchDT.best_score_, gridSearchDT.best_params_)
print()
print("Grid scores on development set:")
print()
means = gridSearchDT.cv_results_['mean_test_score']
for mean, params in zip(means, gridSearchDT.cv_results_['params']):
    print("%0.12f for %r" % (mean, params))
print()
# Out:
# Best parameters set found on development set:
#
# 0.8856302049967969 {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1}
#
# Grid scores on development set:
#
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 1}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 2}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 8}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 16}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 32}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 512}
# 0.878455317104 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1}
# 0.877558456118 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 2}
# 0.877558456118 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4}
# 0.877558456118 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 8}
# 0.877558456118 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 16}
# 0.877558456118 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 32}
# 0.878451313261 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 512}
# 0.885630204997 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1}
# 0.883832479180 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 2}
# 0.885626201153 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4}
# 0.882947629725 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 8}
# 0.883840486867 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32}
# 0.877554452274 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 512}
# 0.870435618193 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1}
# 0.867741031390 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 
for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1}
# 0.851665598975 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2}
# 0.861503042921 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4}
# 0.873122197309 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 8}
# 0.871344490711 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 512}
# 0.852562459962 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 1}
# 0.853439301730 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 2}
# 0.855257046765 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 4}
# 0.873122197309 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 8}
# 0.870447629725 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 512}
# 0.851673606662 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 1}
# 0.856137892377 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 2}
# 0.860614189622 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 4}
# 0.871336483024 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 8}
# 0.871344490711 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 512}
# 0.850772741832 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 1}
# 0.850768737988 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 2}
# 0.857034753363 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 4}
# 0.873122197309 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 8}
# 0.870447629725 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 512}
# 0.848102178091 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 1}
# 0.851673606662 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 2}
# 0.857038757207 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 4}
# 0.872229340167 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 8}
# 0.871344490711 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 512}
# 0.852562459962 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1}
# 0.854348174247 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2}
# 0.856145900064 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4}
# 0.874015054452 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 8}
# 0.871344490711 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 512}
# 0.851681614350 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1}
# 0.849875880846 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 2}
# 0.858828475336 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 4}
# 0.874015054452 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 8}
# 0.871344490711 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 512}
# 0.853459320948 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 1}
# 0.852566463805 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 2}
# 0.865074471493 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 4}
# 0.871336483024 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 8}
# 0.871344490711 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 512}
# 0.849891896220 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 1}
# 0.857026745676 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 2}
# 0.855253042921 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 4}
# 0.874015054452 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 8}
# 0.871344490711 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 512}
# 0.858824471493 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 1}
# 0.855253042921 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 2}
# 0.865082479180 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 4}
# 0.871336483024 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 8}
# 0.870447629725 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 512}
# 0.849875880846 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1}
# 0.847197309417 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2}
# 0.857927610506 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 4}
# 0.870443625881 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 8}
# 0.871344490711 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 16}
# 0.882947629725 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 32}
# 0.875768737988 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 64}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 128}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 256}
# 0.864165598975 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 512}

# %%
test_params = [{"criterion": ['gini', 'entropy'],
        "max_depth": range(1, 21),
        "min_samples_leaf": [1, 2, 4, 8, 16, 32, 64, 128, 256, 512],}]
gridSearchDT = GridSearchCV(dtClass, test_params, cv=10)
gridSearchDT.fit(xTrain, yTrain.values.ravel())
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'max_depth': range(1, 21),
#                           'min_samples_leaf': [1, 2, 4, 8, 16, 32, 64, 128, 256,
#                                                512]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print("Best parameters set found on development set:")
print()
print(gridSearchDT.best_score_, gridSearchDT.best_params_)
print()
print("Grid scores on development set:")
print()
means = gridSearchDT.cv_results_['mean_test_score']
for mean, params in zip(means, gridSearchDT.cv_results_['params']):
    print("%0.12f for %r" % (mean, params))
print()
# Out:
# Best parameters set found on development set:
#
# 0.884740990990991 {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1}
#
# Grid scores on development set:
#
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 1}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 2}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 8}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 16}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 32}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 512}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 2}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 8}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 16}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 32}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 512}
# 0.877574002574 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1}
# 0.877574002574 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 2}
# 0.877574002574 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4}
# 0.876681145431 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 8}
# 0.877582046332 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 16}
# 0.877606177606 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 512}
# 0.864189189189 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1}
# 0.865082046332 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 2}
# 0.865082046332 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4}
# 0.867760617761 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 8}
# 0.868653474903 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 16}
# 0.866891891892 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 32}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 512}
# 0.865958815959 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1}
# 0.866835585586 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2}
# 0.861478442728 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4}
# 0.873970398970 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 8}
# 0.870415057915 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 16}
# 0.866891891892 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 32}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 512}
# 0.865926640927 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1}
# 0.864140926641 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2}
# 0.863248069498 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 4}
# 0.874887387387 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 8}
# 0.873109716860 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 16}
# 0.866891891892 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 32}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 512}
# 0.874002574003 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 1}
# 0.873994530245 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 2}
# 0.861486486486 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 4}
# 0.874887387387 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 8}
# 0.873109716860 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 16}
# 0.867784749035 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 32}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 512}
# 0.860625804376 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1}
# 0.873109716860 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 2}
# 0.866851673102 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 4}
# 0.879367760618 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 8}
# 0.873109716860 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 16}
# 0.866891891892 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 32}
# 0.882054375804 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 512}
# 0.860625804376 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1}
# 0.863264157014 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf':
for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 8}
# 0.881169562420 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 16}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 32}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 512}
# 0.862419562420 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1}
# 0.867784749035 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 2}
# 0.851689189189 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 4}
# 0.858799871300 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 8}
# 0.881169562420 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 16}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 32}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 512}
# 0.857062419562 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 1}
# 0.870463320463 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 2}
# 0.849002574003 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 4}
# 0.859692728443 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 8}
# 0.881169562420 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 16}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 32}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 512}
# 0.864205276705 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 1}
# 0.862427606178 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 2}
# 0.848109716860 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 4}
# 0.858799871300 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 8}
# 0.881169562420 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 16}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 32}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 512}
# 0.865990990991 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 1}
# 0.873149935650 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 2}
# 0.849010617761 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 4}
# 0.857014157014 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 8}
# 0.882062419562 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 16}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 32}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 512}
# 0.859740990991 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1}
# 0.866891891892 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2}
# 0.850796332046 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 4}
# 0.856121299871 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 8}
# 0.881169562420 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 16}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 32}
# 0.882955276705 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 64}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 128}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 256}
# 0.864165057915 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 512}

# %%
test_params = [{"criterion": ['gini', 'entropy'],
        "max_depth": range(1, 21),
        "min_samples_leaf": [1, 2, 4, 8, 16, 32, 64, 128, 256, 512],}]
gridSearchDT = GridSearchCV(dtClass, test_params, cv=12)
gridSearchDT.fit(xTrain, yTrain.values.ravel())
# Out:
# GridSearchCV(cv=12, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'max_depth': range(1, 21),
#                           'min_samples_leaf': [1, 2, 4, 8, 16, 32, 64, 128, 256,
#                                                512]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print("Best parameters set found on development set:")
print()
print(gridSearchDT.best_score_, gridSearchDT.best_params_)
print()
print("Grid scores on development set:")
print()
means = gridSearchDT.cv_results_['mean_test_score']
for mean, params in zip(means, gridSearchDT.cv_results_['params']):
    print("%0.12f for %r" % (mean, params))
print()
# Out:
# Best parameters set found on development set:
#
# 0.8891557995881948 {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 8}
#
# Grid scores on development set:
#
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 1}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 2}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 8}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 16}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 32}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 512}
# 0.878441241516 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1}
# 0.878441241516 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 2}
# 0.878441241516 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4}
# 0.878441241516 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 8}
# 0.878441241516 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 16}
# 0.878441241516 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 32}
# 0.878441241516 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 512}
# 0.880252421261 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1}
# 0.880252421261 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 2}
# 0.880252421261 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4}
# 0.884685045375 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 8}
# 0.885581102722 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 16}
# 0.875781667048 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 512}
# 0.865028978876 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1}
# 0.865038511401 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 2}
# 0.861454282010 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4}
# 0.868594143217 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 8}
# 0.876639594296 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 512}
# 0.865028978876 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1}
# 0.867717150919 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2}
# 0.858766109967 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4}
# 0.868613208267 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 8}
# 0.870367192862 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 512}
# 0.865944101274 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1}
# 0.862378936933 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2}
# 0.847174559597 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 4}
# 0.865067108976 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 8}
# 0.871263250210 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 16}
# 0.873122092580 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 512}
# 0.862407534508 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 1}
# 0.858823305117 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 2}
# 0.850777854038 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 4}
# 0.868603675742 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 8}
# 0.873941889728 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 512}
# 0.861511477160 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1}
# 0.865963166323 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 2}
# 0.851654846336 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 4}
# 0.869518798139 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 8}
# 0.873055364905 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 512}
# 0.854352550904 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1}
# 0.848080149470 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 2}
# 0.850758788988 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 4}
# 0.864132921528 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 8}
# 0.873941889728 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 512}
# 0.860624952337 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1}
# 0.853446961031 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2}
# 0.851702508961 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4}
# 0.865038511401 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 8}
# 0.873055364905 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 16}
# 0.873122092580 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 512}
# 0.861482879585 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 1}
# 0.860615419812 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 2}
# 0.846278502250 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 4}
# 0.868603675742 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 8}
# 0.873941889728 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 512}
# 0.856116068024 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 1}
# 0.853494623656 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 2}
# 0.854333485854 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 4}
# 0.866821093571 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 8}
# 0.873941889728 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 512}
# 0.859719362465 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 1}
# 0.856125600549 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 2}
# 0.852550903683 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 4}
# 0.862350339358 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 8}
# 0.873055364905 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 512}
# 0.858842370167 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 1}
# 0.856125600549 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 2}
# 0.853466026081 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 4}
# 0.864132921528 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 8}
# 0.873941889728 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 512}
# 0.855229543201 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1}
# 0.858832837642 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2}
# 0.848089681995 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4}
# 0.864161519103 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 8}
# 0.873941889728 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 512}
# 0.857059787997 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1}
# 0.845439640052 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 2}
# 0.851654846336 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 4}
# 0.865934568749 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 8}
# 0.873055364905 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 16}
# 0.873122092580 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 512}
# 0.860577289712 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 1}
# 0.860615419812 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 2}
# 0.846297567300 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 4}
# 0.867707618394 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 8}
# 0.873055364905 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 16}
# 0.874018149928 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 512}
# 0.856144665599 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 1}
# 0.852569968733 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 2}
# 0.856116068024 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 4}
# 0.869499733089 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 8}
# 0.873055364905 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 16}
# 0.873122092580 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 512}
# 0.855258140776 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 1}
# 0.857012125372 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 2}
# 0.849891329215 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 4}
# 0.865934568749 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 8}
# 0.873055364905 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 16}
# 0.873122092580 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 512}
# 0.857946312819 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1}
# 0.854381148479 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2}
# 0.849862731640 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 4}
# 0.865028978876 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 8}
# 0.873941889728 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 16}
# 0.873122092580 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 32}
# 0.882025470907 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 512}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 1}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 2}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 8}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 16}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 32}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 512}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 2}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 8}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 16}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 32}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 512}
# 0.886486692595 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1}
# 0.886486692595 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 2}
# 0.886486692595 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4}
# 0.886486692595 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 8}
# 0.886486692595 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 16}
# 0.886486692595 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 512}
# 0.883817585602 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1}
# 0.882921528254 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 2}
# 0.882921528254 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4}
# 0.889155799588 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 8}
# 0.885600167772 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 512}
# 0.878479371616 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1}
# 0.875810264623 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2}
# 0.870414855487 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4}
# 0.880242888736 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 8}
# 0.886477160070 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 512}
# 0.870433920537 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1}
# 0.875810264623 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2}
# 0.871301380310 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 4}
# 0.874857012125 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 8}
# 0.883808053077 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 512}
# 0.873112560055 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 1}
# 0.874885609700 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 2}
# 0.863255929231 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 4}
# 0.874818882025 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 8}
# 0.882015938382 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 512}
# 0.859690764890 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1}
# 0.860567757188 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 2}
# 0.844438724929 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 4}
# 0.867650423244 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 8}
# 0.881129413559 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 512}
# 0.863265461756 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1}
# 0.865038511401 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 2}
# 0.853370700831 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 4}
# 0.864066193853 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 8}
# 0.882015938382 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 512}
# 0.857002592847 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1}
# 0.865038511401 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2}
# 0.853389765881 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4}
# 0.867650423244 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 8}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 512}
# 0.859700297415 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 1}
# 0.869518798139 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 2}
# 0.851588118661 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 4}
# 0.863170136506 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 8}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 512}
# 0.865934568749 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 1}
# 0.867726683444 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 2}
# 0.856049340349 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 4}
# 0.864066193853 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 8}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 512}
# 0.859690764890 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 1}
# 0.870395790437 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 2}
# 0.848013421795 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 4}
# 0.865858308549 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 8}
# 0.882015938382 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 13, 'min_samples_leaf': 512}
# 0.865934568749 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 1}
# 0.869509265614 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 2}
# 0.851607183711 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 4}
# 0.866754365896 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 8}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 14, 'min_samples_leaf': 512}
# 0.858785175017 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1}
# 0.873074429955 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2}
# 0.849796003966 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4}
# 0.864962251201 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 8}
# 0.882025470907 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 512}
# 0.859700297415 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1}
# 0.869518798139 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 2}
# 0.846230839625 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 4}
# 0.865858308549 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 8}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 512}
# 0.857898650194 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 1}
# 0.871291847785 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 2}
# 0.848013421795 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 4}
# 0.864066193853 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 8}
# 0.882015938382 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 512}
# 0.865972698848 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 1}
# 0.867707618394 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 2}
# 0.850701593838 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 4}
# 0.864066193853 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 8}
# 0.882025470907 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 512}
# 0.859700297415 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 1}
# 0.873093495005 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 2}
# 0.852474643484 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 4}
# 0.864066193853 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 8}
# 0.882015938382 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 19, 'min_samples_leaf': 512}
# 0.861501944635 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1}
# 0.872178372607 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2}
# 0.853370700831 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 4}
# 0.862274079158 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 8}
# 0.882025470907 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 16}
# 0.879318233814 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 32}
# 0.882911995729 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 64}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 128}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 256}
# 0.864171051628 for {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 512}

# %% [markdown]
# # Best Parameters for Knn and Dt
# **Best Params for Knn:** 0.8650624599615631 {'n_neighbors': 21}
#
# **Best Params for DT:** 0.8891557995881948 {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 8}

# %%
trainX5, testXdrop5, trainY5, testYdrop5 = train_test_split(xTrain, yTrain, shuffle=True, test_size=.05)
trainX10, testXdrop10, trainY10, testYdrop10 = train_test_split(xTrain, yTrain, shuffle=True, test_size=.10)
trainX20, testXdrop20, trainY20, testYdrop20 = train_test_split(xTrain, yTrain, shuffle=True, test_size=.20)

# %%
knnAll = KNeighborsClassifier(n_neighbors=21)
knn5 = KNeighborsClassifier(n_neighbors=21)
knn10 = KNeighborsClassifier(n_neighbors=21)
knn20 = KNeighborsClassifier(n_neighbors=21)

# %%
knnAll.fit(xTrain, yTrain.values.ravel())
knn5.fit(trainX5, trainY5.values.ravel())
knn10.fit(trainX10, trainY10.values.ravel())
knn20.fit(trainX20, trainY20.values.ravel())
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=21, p=2,
#                      weights='uniform')

# %%
acc = knnAll.score(xTest,yTest)
yHatTest = knnAll.predict(xTest)
# calculate auc for test
testAuc = metrics.roc_auc_score(yTest['label'], yHatTest)
print(acc, testAuc)

acc = knn5.score(xTest, yTest)
yHatTest = knn5.predict(xTest)
# calculate auc for test
testAuc = metrics.roc_auc_score(yTest['label'], yHatTest)
print(acc, testAuc)

acc = knn10.score(xTest,yTest)
yHatTest = knn10.predict(xTest)
# calculate auc for test
testAuc = metrics.roc_auc_score(yTest['label'], yHatTest)
print(acc, testAuc)

acc = knn20.score(xTest,yTest)
yHatTest = knn20.predict(xTest)
# calculate auc for test
testAuc = metrics.roc_auc_score(yTest['label'], yHatTest)
print(acc, testAuc)
# Out:
# 0.8604166666666667 0.5040778498609824
# 0.8625 0.5052826691380907
# 0.8666666666666667 0.5076923076923077
# 0.8625 0.5052826691380907

# %%
dtAll = DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=8)
dt5 = DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=8)
dt10 = DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=8)
dt20 = DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=8)

# %%
dtAll.fit(xTrain, yTrain.values.ravel())
dt5.fit(trainX5, trainY5.values.ravel())
dt10.fit(trainX10, trainY10.values.ravel())
dt20.fit(trainX20, trainY20.values.ravel())
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=8, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
acc = dtAll.score(xTest,yTest)
yHatTest = dtAll.predict(xTest)
# calculate auc for test
testAuc = metrics.roc_auc_score(yTest['label'], yHatTest)
print(acc, testAuc)

acc = dt5.score(xTest, yTest)
yHatTest = dt5.predict(xTest)
# calculate auc for test
testAuc = metrics.roc_auc_score(yTest['label'], yHatTest)
print(acc, testAuc)

acc = dt10.score(xTest,yTest)
yHatTest = dt10.predict(xTest)
# calculate auc for test
testAuc = metrics.roc_auc_score(yTest['label'], yHatTest)
print(acc, testAuc)

acc = dt20.score(xTest,yTest)
yHatTest = dt20.predict(xTest)
# calculate auc for test
testAuc = metrics.roc_auc_score(yTest['label'], yHatTest)
print(acc, testAuc)
# Out:
# 0.86875 0.5672845227062094
# 0.8770833333333333 0.6175162187210379
# 0.8770833333333333 0.5980537534754403
# 0.8875 0.6559777571825766
